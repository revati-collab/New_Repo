# %%
import pandas as pd
df = pd.read_csv('tested.csv')

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S

# %%
 df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex  Age  \
# 416         1308         0       3       Ware, Mr. Frederick  male  NaN
# 417         1309         0       3  Peter, Master. Michael J  male  NaN
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 416      0      0  359309   8.0500   NaN        S
# 417      1      1    2668  22.3583   NaN        C

# %%
df.loc[10:15][['PassengerId','Pclass','Survived','Name']]
# Out:
#     PassengerId  Pclass  Survived  \
# 10          902       3         0
# 11          903       1         0
# 12          904       1         1
# 13          905       2         0
# 14          906       1         1
# 15          907       2         1
#
#                                                  Name
# 10                                   Ilieff, Mr. Ylio
# 11                         Jones, Mr. Charles Cresson
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 13                               Howard, Mr. Benjamin
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15      del Carlo, Mrs. Sebastiano (Argenia Genovesi)

# %%
df.iloc[10:15, 0:3]
# Out:
#     PassengerId  Survived  Pclass
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# condition 

10 > 40
# Out:
# False

# %%
newdf = df[df['Age'] > 30]

# %%
newdf.head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 0           892         0       3                  Kelly, Mr. James    male
# 1           893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2           894         0       2         Myles, Mr. Thomas Francis    male
# 11          903         0       1        Jones, Mr. Charles Cresson    male
# 13          905         0       2              Howard, Mr. Benjamin    male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 0   34.5      0      0  330911   7.8292   NaN        Q
# 1   47.0      1      0  363272   7.0000   NaN        S
# 2   62.0      0      0  240276   9.6875   NaN        Q
# 11  46.0      0      0     694  26.0000   NaN        S
# 13  63.0      1      0   24065  26.0000   NaN        S

# %%
newdf.shape
# Out:
# (132, 12)

# %%
df.shape
# Out:
# (418, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
Data = df['Age'].isnull()

# %%
list = []

# %%
for x in Data:
    if x == True:
        list.append(x)

# %%
print(list)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413     True
# 414    False
# 415    False
# 416     True
# 417     True
# Name: Age, Length: 418, dtype: bool

# %%
df.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 413         True      True    True  True  True  False   True   True    True
# 414         True      True    True  True  True   True   True   True    True
# 415         True      True    True  True  True   True   True   True    True
# 416         True      True    True  True  True  False   True   True    True
# 417         True      True    True  True  True  False   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# ...

# %%
df[df['Age'].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 409         1301         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df.size
# Out:
# 5016

# %%
df.isnull().sum().sum()
# Out:
# 414

# %%
(df.isnull().sum().sum() / df.size)*100
# Out:
# 8.253588516746412

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.fillna('Class A',inplace = True)
# Out:
# C:\Users\siddh\AppData\Local\Temp\ipykernel_20228\17383704.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Class A' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('Class A',inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.fillna('na',inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Alice', 'Charlie', 'Bob', 'David'],
    'Age': [25, 30, 25, 35, 30, 40],
    'City': ['New York', 'Los Angeles', 'New York', 'Chicago', 'Los Angeles', 'San Francisco']
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2    Alice   25       New York
# 3  Charlie   35        Chicago
# 4      Bob   30    Los Angeles
# 5    David   40  San Francisco

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Age, City]
# Index: []

# %%
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2    Alice   25       New York
# 3  Charlie   35        Chicago
# 4      Bob   30    Los Angeles
# 5    David   40  San Francisco

# %%
df.drop_duplicates(inplace = True)

# %%
newdf = pd.read_csv('DataSets/data_science_job.csv')

# %%
newdf.duplicated().sum()
# Out:
# 0

# %%
newdf.isnull().sum().sum()
# Out:
# 21555

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=19158, step=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.rename(columns = {'Ticket':'Price'}, inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
A = df[['Survived']].head()

# %%
A
# Out:
#    Survived
# 0         0
# 1         1
# 2         0
# 3         0
# 4         1

# %%
A.replace([0, 1],['Die','Survived'])
# Out:
#    Survived
# 0       Die
# 1  Survived
# 2       Die
# 3       Die
# 4  Survived

# %%
# Task

# %% [markdown]
# 📢 Assignment Instructions – Pandas Data Exploration & Cleaning
# Dear Students,
#
# You are required to complete the following assignment using the Netflix Movies and TV Shows dataset. This will help you apply the Pandas skills we've covered in class, including data loading, exploration, selection, and cleaning.
#
# 🧠 What You Need to Do:
# Download the Dataset
#
# Get the dataset from this link:
# 👉 Netflix Dataset on Kaggle
#
# Do All Your Work in a Jupyter Notebook
#
# Use Jupyter Notebook (Anaconda, VSCode, etc.) or Google Colab.
#
# Name your notebook: yourname_netflix_assignment.ipynb
#
# Follow These Tasks in Your Notebook
#
# Load the dataset
#
# Explore the data (head, shape, info, describe, etc.)
#
# Select and filter rows and columns
#
# Handle missing values and duplicates
#
# Rename and replace values
#
# Export the cleaned dataset as netflix_cleaned.csv
#
# 📤 How to Submit:
# If you’re using Jupyter Notebook (locally):
#
# Upload your .ipynb notebook to the Google Form I’ll share.
#
# If you're using Google Colab:
#
# Make sure your notebook is public or viewable.
#
#
# 🚨 Important Notes:
# Make sure your notebook runs from top to bottom without errors.
#
# Add comments to your code where necessary to explain what you're doing.
#
# Do not copy from each other. Plagiarism will result in no marks.
#
# If you have any questions, feel free to ask. Good luck, and enjoy exploring real-world data!
